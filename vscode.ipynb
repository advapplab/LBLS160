# %%
import pandas as pd
import hashlib as hb

# %%
vscode = pd.read_csv('./data/1092_viscode_logs.csv')

# %%
vscode['username'] = vscode['username'].str.split('@',expand=True).get(0)
vscode = vscode[vscode['username'].str.isdigit() == True]
vscode = vscode[vscode['username'].apply(lambda x: len(str(x))>=9)]

# %%
def md5(i):
    hl = hb.md5()
    
    hl.update(str(i).encode(encoding='utf-8'))

    #print('加密前為 ：' + str(i))
    #print('加密後為 ：' + hl.hexdigest())
    
    return hl.hexdigest()

vscode['username'] = vscode['username'].apply(md5)

# %%
vscode.drop(columns=["lti.lastName", "lti.name","lti.username","lti.firstName","lti.email","notebookPath","notebookName","notebookName","lti.contextLable","lti.contextTitle"],inplace=True)

# %%
vscode.to_csv('./output/vscode.csv',encoding='utf8')

# %%
vscode
# Out:
#                         _id   _index  _score    _type  \
# 0      NIxRe3sBhZd_WuicrXaC  viscode     NaN  jupyter
# 1      gkVRe3sB4yEMcndfrQdT  viscode     NaN  jupyter
# 2      BoxRe3sBhZd_WuicHnYI  viscode     NaN  jupyter
# 3      gzxgXnsB4yEMcndfgGOR  viscode     NaN  jupyter
# 4      JINgXnsBhZd_WuicgHhR  viscode     NaN  jupyter
# ...                     ...      ...     ...      ...
# 27869  QOJdNHoB4yEMcndf2ePR  viscode     NaN  jupyter
# 27870  Di1dNHoBhZd_WuicsXS1  viscode     NaN  jupyter
# 27871  FOJdNHoB4yEMcndfNuOS  viscode     NaN  jupyter
# 27872  6C1dNHoBhZd_WuicJ3Pp  viscode     NaN  jupyter
# 27873  EOJdNHoB4yEMcndfJeNj  viscode     NaN  jupyter
#
#                                  cellId  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 27869  5f1af330b9c246478ca1d1662b2ba28a
# 27870  5f1af330b9c246478ca1d1662b2ba28a
# 27871  5f1af330b9c246478ca1d1662b2ba28a
# 27872                               NaN
# 27873  5f1af330b9c246478ca1d1662b2ba28a
#
#                                                     code codeLength errorName  \
# 0                                                    NaN        NaN       NaN
# 1                                                    NaN      1,394       NaN
# 2                                                    NaN        NaN       NaN
# 3                                                    NaN        NaN       NaN
# 4                                                    NaN          1       NaN
# ...                                                  ...        ...       ...
# 27869  pur=int(input())\ngift=int(input())\ntmp=pur//...        NaN       NaN
# 27870  pur=int(input())\ngift=int(input())\ntmp=pur//...        NaN       NaN
# 27871  pur=int(input())\ngift=int(input())\ntmp=pur//...        NaN       NaN
# 27872                                                NaN      2,564       NaN
# 27873  pur=int(input())\ngift=int(input())\ntmp=pur//...        NaN       NaN
#
#       errorValue           event isError  \
# 0            NaN   notebook_open     NaN
# 1            NaN      code_speed     NaN
# 2            NaN       tree_open     NaN
# 3            NaN   notebook_open     NaN
# 4            NaN      code_speed     NaN
# ...          ...             ...     ...
# 27869        NaN  code_execution     NaN
# 27870        NaN  code_execution     NaN
# 27871        NaN  code_execution     NaN
# 27872        NaN      code_speed     NaN
# 27873        NaN  code_execution     NaN
#
#                                    kernelId  lti.contextId lti.locale  \
# 0                                       NaN            287      zh_tw
# 1                                       NaN            287      zh_tw
# 2                                       NaN            287      zh_tw
# 3                                       NaN            288      zh_tw
# 4                                       NaN            288      zh_tw
# ...                                     ...            ...        ...
# 27869  a44f7387-e046-4ae3-a2d6-c073e944217d            287      zh_tw
# 27870  a44f7387-e046-4ae3-a2d6-c073e944217d            287      zh_tw
# 27871  a44f7387-e046-4ae3-a2d6-c073e944217d            287      zh_tw
# 27872                                   NaN            287      zh_tw
# 27873  a44f7387-e046-4ae3-a2d6-c073e944217d            287      zh_tw
#
#         lti.roles text                    timestamp  \
# 0      Instructor  NaN  Aug 25, 2021 @ 03:19:15.585
# 1      Instructor  NaN  Aug 25, 2021 @ 03:19:15.537
# 2      Instructor  NaN  Aug 25, 2021 @ 03:18:38.852
# 3         Learner  NaN  Aug 19, 2021 @ 12:26:27.856
# 4         Learner  NaN  Aug 19, 2021 @ 12:26:27.792
# ...           ...  ...                          ...
# 27869     Learner  NaN  Jun 22, 2021 @ 15:36:43.725
# 27870     Learner  NaN  Jun 22, 2021 @ 15:36:33.460
# 27871     Learner  NaN  Jun 22, 2021 @ 15:36:01.937
# 27872     Learner  NaN  Jun 22, 2021 @ 15:35:58.184
# 27873     Learner  NaN  Jun 22, 2021 @ 15:35:57.537
#
#                                username
# 0      4281b43958059de8ff96710b6a2d947a
# 1      4281b43958059de8ff96710b6a2d947a
# 2      4281b43958059de8ff96710b6a2d947a
# 3      9879db96946fbb8a3e255ab8815c577e
# 4      9879db96946fbb8a3e255ab8815c577e
# ...                                 ...
# 27869  a23402a174a55c4211136df4425a724e
# 27870  a23402a174a55c4211136df4425a724e
# 27871  a23402a174a55c4211136df4425a724e
# 27872  a23402a174a55c4211136df4425a724e
# 27873  a23402a174a55c4211136df4425a724e
#
# [27248 rows x 18 columns]
